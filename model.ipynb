# %%
import pandas as pd 
import numpy as np

# %%
test_path = '/home/abdulla-ovais/Desktop/vnb-foml-2024-hackathon./foml24_hackathon/test.csv'
train_path = '/home/abdulla-ovais/Desktop/vnb-foml-2024-hackathon./foml24_hackathon/train.csv'

pd1 = pd.read_csv(test_path)
pd2 = pd.read_csv(train_path)

print(pd1)
print(pd2)
pd1.head()
pd2.head()
# Out:
#           UID  AgriculturalPostalZone  AgricultureZoningCode  \
# 0      130000                  475712                    0.0
# 1      129101                  101762                   46.0
# 2      147876                  309344                   19.0
# 3      122624                  689775                   19.0
# 4      159920                  445333                   20.0
# ...       ...                     ...                    ...
# 15916   99588                  276561                    0.0
# 15917   86801                  258901                   19.0
# 15918   68439                  811733                   24.0
# 15919   13210                  815396                   46.0
# 15920  151497                  960465                    0.0
#
#        CropFieldConfiguration  CropSpeciesVariety  CultivatedAndWildArea  \
# 0                         NaN                 5.0                    NaN
# 1                         NaN                 3.0                    NaN
# 2                         NaN                 2.0                    NaN
# 3                         NaN                 3.0                    NaN
# 4                         NaN                 1.0                    NaN
# ...                       ...                 ...                    ...
# 15916                     NaN                 5.0                    NaN
# 15917                     NaN                 2.0                    NaN
# 15918                     1.0                 3.0                    NaN
# 15919                     NaN                 3.0                    NaN
# 15920                     NaN                 3.0                    NaN
#
#        CultivatedAreaSqft1  DistrictId  FarmClassification  FarmEquipmentArea  \
# 0                   2870.0         1.0                 NaN                NaN
# 1                   1291.0         3.0                 NaN              504.0
# 2                   1074.0         1.0                 NaN                NaN
# 3                   1595.0         1.0                 NaN                NaN
# 4                    768.0         2.0                 NaN                0.0
# ...                    ...         ...                 ...                ...
# 15916               3681.0         1.0                 NaN                NaN
# 15917               2126.0         1.0                 NaN                NaN
# 15918               1356.0         2.0                 NaN              462.0
# 15919               1548.0         3.0                 NaN              462.0
# 15920               1225.0         1.0                 NaN                NaN
#
#        ...  TotalReservoirSize  TotalTaxAssessed  TotalValue  TownId  \
# 0      ...                 NaN          9540.432    319373.4    52.0
# 1      ...                 NaN         11064.284    805200.0    47.0
# 2      ...                 NaN          5789.762    305867.2    14.0
# 3      ...                 NaN          9440.486    524597.8     NaN
# 4      ...                 NaN          8384.640    692973.6    10.0
# ...    ...                 ...               ...         ...     ...
# 15916  ...                 NaN         17066.632    833455.8    91.0
# 15917  ...                 NaN         15321.548    873846.0     1.0
# 15918  ...                 NaN         14688.696    882241.4    31.0
# 15919  ...                 NaN          9634.592    597882.0    79.0
# 15920  ...                 NaN          2080.870     72072.0    70.0
#
#        TypeOfIrrigationSystem  UndergroundStorageSqft  ValuationYear  \
# 0                         1.0                     NaN         2020.0
# 1                         NaN                     NaN         2020.0
# 2                         NaN                     NaN         2020.0
# 3                         1.0                     NaN         2020.0
# 4                         NaN                     NaN         2020.0
# ...                       ...                     ...            ...
# 15916                     1.0                     NaN         2020.0
# 15917                     1.0                     NaN         2020.0
# 15918                     NaN                     NaN         2018.0
# 15919                     NaN                     NaN         2018.0
# 15920                     NaN                     NaN         2020.0
#
#        WaterAccessPoints  WaterAccessPointsCalc  WaterReservoirCount
# 0                    3.0                    3.0                  NaN
# 1                    2.0                    2.0                  NaN
# 2                    2.0                    2.0                  1.0
# 3                    2.0                    2.0                  NaN
# 4                    1.0                    1.0                  NaN
# ...                  ...                    ...                  ...
# 15916                3.0                    3.0                  NaN
# 15917                3.0                    3.0                  NaN
# 15918                2.0                    2.0                  NaN
# 15919                1.5                    1.5                  NaN
# 15920                1.0                    1.0                  NaN
#
# [15921 rows x 57 columns]
#            UID  AgriculturalPostalZone  AgricultureZoningCode  \
# 0        12998                  291674                    0.0
# 1        20860                  164397                   28.0
# 2        75725                  616532                    0.0
# 3       106521                  942111                   43.0
# 4        99467                  475557                   38.0
# ...        ...                     ...                    ...
# 112564   26998                  380364                   41.0
# 112565  135304                  369784                   24.0
# 112566  153756                  414700                   37.0
# 112567  129907                  566488                   19.0
# 112568  103354                  540570                   28.0
#
#         CropFieldConfiguration  CropSpeciesVariety  CultivatedAndWildArea  \
# 0                          NaN                 3.0                    NaN
# 1                          NaN                 4.0                    NaN
# 2                          NaN                 2.0                    NaN
# 3                          NaN                 7.0                    NaN
# 4                          NaN                 3.0                    NaN
# ...                        ...                 ...                    ...
# 112564                     NaN                 2.0                    NaN
# 112565                     NaN                 4.0                    NaN
# 112566                     NaN                 4.0                    NaN
# 112567                     NaN                 2.0                    NaN
# 112568                     NaN                 3.0                    NaN
#
#         CultivatedAreaSqft1  DistrictId  FarmClassification  \
# 0                    1136.0         1.0                 NaN
# 1                    2083.0         1.0                 NaN
# 2                     922.0         1.0                 NaN
# 3                       NaN         1.0                 NaN
# 4                    2225.0         3.0                 NaN
# ...                     ...         ...                 ...
# 112564               1672.0         3.0                 NaN
# 112565               3340.0         2.0                 NaN
# 112566                  NaN         1.0                 NaN
# 112567               1178.0         1.0                 NaN
# 112568               1136.0         1.0                 NaN
#
#         FarmEquipmentArea  ...  TotalTaxAssessed  TotalValue  TownId  \
# 0                     NaN  ...          8636.716    456255.6   118.0
# 1                     NaN  ...         18464.292    996887.6    24.0
# 2                     NaN  ...         15594.568   1043780.0     9.0
# 3                     NaN  ...          8494.618    435734.8   114.0
# 4                     0.0  ...         13517.284    885400.0     6.0
# ...                   ...  ...               ...         ...     ...
# 112564              460.0  ...         13467.652   1106200.0    47.0
# 112565              620.0  ...         21732.964   1643115.8     7.0
# 112566                NaN  ...         25067.856   1464648.6     1.0
# 112567                NaN  ...         10530.652    679200.0     1.0
# 112568                NaN  ...          8902.344    515822.8    49.0
#
#         TypeOfIrrigationSystem  UndergroundStorageSqft  ValuationYear  \
# 0                          NaN                     NaN         2018.0
# 1                          1.0                     NaN         2018.0
# 2                          1.0                     NaN         2018.0
# 3                          NaN                     NaN         2020.0
# 4                          NaN                     NaN         2020.0
# ...                        ...                     ...            ...
# 112564                     NaN                     NaN         2018.0
# 112565                     NaN                     NaN         2020.0
# 112566                     NaN                     NaN         2020.0
# 112567                     1.0                     NaN         2020.0
# 112568                     NaN                     NaN         2020.0
#
#         WaterAccessPoints  WaterAccessPointsCalc  WaterReservoirCount  Target
# 0                     2.0                    2.0                  NaN    high
# 1                     3.0                    3.0                  1.0  medium
# 2                     1.0                    1.0                  NaN  medium
# 3                     3.0                    3.0                  NaN     low
# 4                     4.0                    4.0                  NaN  medium
# ...                   ...                    ...                  ...     ...
# 112564                2.0                    2.0                  NaN  medium
# 112565                3.0                    3.0                  NaN  medium
# 112566                4.0                    4.0                  NaN    high
# 112567                2.0                    2.0                  1.0  medium
# 112568                1.0                    1.0                  1.0     low
#
# [112569 rows x 58 columns]
#       UID  AgriculturalPostalZone  AgricultureZoningCode  \
# 0   12998                  291674                    0.0
# 1   20860                  164397                   28.0
# 2   75725                  616532                    0.0
# 3  106521                  942111                   43.0
# 4   99467                  475557                   38.0
#
#    CropFieldConfiguration  CropSpeciesVariety  CultivatedAndWildArea  \
# 0                     NaN                 3.0                    NaN
# 1                     NaN                 4.0                    NaN
# 2                     NaN                 2.0                    NaN
# 3                     NaN                 7.0                    NaN
# 4                     NaN                 3.0                    NaN
#
#    CultivatedAreaSqft1  DistrictId  FarmClassification  FarmEquipmentArea  \
# 0               1136.0         1.0                 NaN                NaN
# 1               2083.0         1.0                 NaN                NaN
# 2                922.0         1.0                 NaN                NaN
# 3                  NaN         1.0                 NaN                NaN
# 4               2225.0         3.0                 NaN                0.0
#
#    ...  TotalTaxAssessed  TotalValue  TownId  TypeOfIrrigationSystem  \
# 0  ...          8636.716    456255.6   118.0                     NaN
# 1  ...         18464.292    996887.6    24.0                     1.0
# 2  ...         15594.568   1043780.0     9.0                     1.0
# 3  ...          8494.618    435734.8   114.0                     NaN
# 4  ...         13517.284    885400.0     6.0                     NaN
#
#    UndergroundStorageSqft  ValuationYear  WaterAccessPoints  \
# 0                     NaN         2018.0                2.0
# 1                     NaN         2018.0                3.0
# 2                     NaN         2018.0                1.0
# 3                     NaN         2020.0                3.0
# 4                     NaN         2020.0                4.0
#
#    WaterAccessPointsCalc  WaterReservoirCount  Target
# 0                    2.0                  NaN    high
# 1                    3.0                  1.0  medium
# 2                    1.0                  NaN  medium
# 3                    3.0                  NaN     low
# 4                    4.0                  NaN  medium
#
# [5 rows x 58 columns]
